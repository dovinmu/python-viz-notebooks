# %%
import pandas
import matplotlib.pyplot as plt

# %%
cities = pandas.read_csv('US_cities.csv')
cities.sample(5)
# Out:
#            id Country        City  AccentCity Region  Population   Latitude  \
# 3697  3028455      us    live oak    Live Oak     TX     10193.0  29.565000
# 778   2927792      us       brent       Brent     FL     22735.0  30.468611
# 1322  2940234      us   northlake   Northlake     IL     11497.0  41.917222
# 2266  2976128      us  ellisville  Ellisville     MO      9362.0  38.592500
# 893   2929242      us   melbourne   Melbourne     FL     76326.0  28.083333
#
#       Longitude
# 3697 -98.336111
# 778  -87.236111
# 1322 -87.895556
# 2266 -90.586944
# 893  -80.608333

# %%
import geopandas
cafes = geopandas.read_file('cafes_us_OSM.geojson')
cafes.sample()
# Out:
#                    id              @id amenity building      cuisine  \
# 6397  node/2037620890  node/2037620890    cafe     None  coffee_shop
#
#            name operator wheelchair website addr:city  \
# 6397  Starbucks     None       None    None      None
#
#                    ...                karaoke gambling reservation  \
# 6397               ...                   None     None        None
#
#      tourism:disused indoor:level landuse diet:raw name:it amenity:ice_cream  \
# 6397            None         None    None     None    None              None
#
#                              geometry
# 6397  POINT (-122.9160315 46.9987745)
#
# [1 rows x 400 columns]

# %%
cafes.sample().T.dropna()
# Out:
#                                                  19338
# id                                     node/4831902733
# @id                                    node/4831902733
# amenity                                           cafe
# name                   Three Fifty Bakery & Coffee Bar
# website                          http://threefifty.com
# addr:city                                   Washington
# addr:housenumber                                  1926
# addr:street                      17th Street Northwest
# opening_hours     Mo-Fr 07:00-19:00; Sa-Su 08:00-18:00
# addr:postcode                                    20009
# addr:state                                          DC
# geometry                POINT (-77.0386839 38.9166304)

# %%
cafes['count'] = 1
cafes[['cuisine', 'count']].groupby('cuisine').sum().sort_values('count', ascending=False)[:10]
# Out:
#              count
# cuisine
# coffee_shop   6166
# donut          625
# ice_cream      290
# sandwich       284
# american       220
# coffee          78
# cafe            73
# regional        71
# bagel           64
# tea             52

# %%
sorted(list(cafes.columns))
# Out:
# ['@id',
#  'Door',
#  'FIXME',
#  'Notes',
#  'access',
#  'addr',
#  'addr.source:street',
#  'addr:city',
#  'addr:country',
#  'addr:county',
#  'addr:direction',
#  'addr:door',
#  'addr:flats',
#  'addr:floor',
#  'addr:full',
#  'addr:house',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:interpolation',
#  'addr:place',
#  'addr:postcode',
#  'addr:province',
#  'addr:state',
#  'addr:street',
#  'addr:street:name',
#  'addr:street:prefix',
#  'addr:street:type',
#  'addr:street_direction_prefix',
#  'addr:suburb',
#  'addr:suite',
#  'addr:unit',
#  'addr:unit_1',
#  'address',
#  'aka',
#  'alcohol',
#  'alt_name',
#  'alt_name2',
#  'alt_name_1',
#  'alt_name_2',
#  'amenity',
#  'amenity:bar',
#  'amenity:historic',
#  'amenity:ice_cream',
#  'amenity_1',
#  'amenity_2',
#  'approximate',
#  'atm',
#  'atm:operator',
#  'attribution',
#  'automatic_door',
#  'bakery',
#  'bar',
#  'beer',
#  'bicycle_parking',
#  'black_owned',
#  'branch',
#  'brand',
#  'brand:wikidata',
#  'brewery',
#  'building',
#  'building:levels',
#  'building:part',
#  'bus',
#  'cafe',
#  'camera:mount',
#  'capacity',
#  'capacity:disabled',
#  'capacity_1',
#  'cat',
#  'cater',
#  'catering',
#  'check_date',
#  'checked_exists:date',
#  'chocolates',
#  'circuits',
#  'cityracks.housenum',
#  'cityracks.installed',
#  'cityracks.large',
#  'cityracks.rackid',
#  'cityracks.small',
#  'cityracks.street',
#  'cmt',
#  'coffee',
#  'colour',
#  'comment',
#  'contact:email',
#  'contact:facebook',
#  'contact:fax',
#  'contact:foursquare',
#  'contact:google_plus',
#  'contact:instagram',
#  'contact:phone',
#  'contact:phone_tollfree',
#  'contact:twitter',
#  'contact:website',
#  'contact:yelp',
#  'contact:youtube',
#  'cost:coffee',
#  'count',
#  'craft',
#  'created_by',
#  'crop',
#  'cuisine',
#  'cuisine_1',
#  'cuisine_2',
#  'cuisine_3',
#  'cusine',
#  'dataset',
#  'dcgis:lot',
#  'dcgis:square',
#  'delivery',
#  'description',
#  'designation',
#  'dessert:type',
#  'diaper',
#  'diet:gluten_free',
#  'diet:kosher',
#  'diet:lactose_free',
#  'diet:raw',
#  'diet:vegan',
#  'diet:vegetarian',
#  'dispensing',
#  'disused',
#  'disused:name',
#  'disused:shop',
#  'disused:website',
#  'double',
#  'drink',
#  'drink:beer',
#  'drink:club-mate',
#  'drink:espresso',
#  'drink:juice',
#  'drink:liquor',
#  'drink:soy_milk',
#  'drink:wine',
#  'drinking_water',
#  'drive_in',
#  'drive_through',
#  'ele',
#  'email',
#  'emergency',
#  'entrance',
#  'facebook',
#  'fair_trade',
#  'fax',
#  'feature',
#  'floor',
#  'food',
#  'former_name',
#  'gambling',
#  'geometry',
#  'gis_pin',
#  'gluten_free',
#  'gnis:ST_alpha',
#  'gnis:ST_num',
#  'gnis:county_id',
#  'gnis:county_name',
#  'gnis:created',
#  'gnis:feature_id',
#  'gnis:import_uuid',
#  'gnis:reviewed',
#  'gnis:state_id',
#  'gst_number',
#  'highway',
#  'historic',
#  'hst_number',
#  'ice_cream',
#  'id',
#  'import',
#  'import_uuid',
#  'in_store',
#  'indoor',
#  'indoor:level',
#  'indoor_seating',
#  'inside_at_operator',
#  'inside_atm',
#  'int_name',
#  'internet',
#  'internet_1',
#  'internet_2',
#  'internet_access',
#  'internet_access:fee',
#  'internet_access:operator',
#  'internet_access:ssid',
#  'internet_access:type',
#  'is_in',
#  'is_in:city',
#  'is_in:country',
#  'is_in:country_code',
#  'is_in:state',
#  'is_in:state_code',
#  'is_in:theme_park',
#  'karaoke',
#  'key',
#  'landuse',
#  'lanes',
#  'layer',
#  'lbcs:activity:code',
#  'lbcs:activity:name',
#  'lbcs:function:code',
#  'lbcs:function:name',
#  'leisure',
#  'level',
#  'level:ref',
#  'linncounty:objectid',
#  'liquor',
#  'loc_name',
#  'location',
#  'lounge',
#  'lunch',
#  'manager',
#  'manager:phone',
#  'microbrewery',
#  'motorcar',
#  'music',
#  'name',
#  'name:ar',
#  'name:de',
#  'name:en',
#  'name:es',
#  'name:etymology:wikidata',
#  'name:fi',
#  'name:fr',
#  'name:he',
#  'name:it',
#  'name:ko',
#  'name:nl',
#  'name:pt',
#  'name:ru',
#  'name:vi',
#  'name:zh',
#  'name:zh_pinyin',
#  'name_1',
#  'name_2',
#  'name_3',
#  'name_4',
#  'name_5',
#  'name_6',
#  'name_alt',
#  'newspapers',
#  'note',
#  'note:cuisine',
#  'note:name',
#  'odbl',
#  'office',
#  'official_name',
#  'old_name',
#  'old_name:vi',
#  'old_postal_code',
#  'opendata:type',
#  'opening_hours',
#  'opening_hours:kitchen',
#  'opening_hours:url',
#  'operator',
#  'operator:url',
#  'operator:wikidata',
#  'operator:wikipedia',
#  'organic',
#  'outdoor_seating',
#  'outside_seating',
#  'owner',
#  'paloalto_ca:id',
#  'pastry_shop',
#  'patio',
#  'payment:account_cards',
#  'payment:american_express',
#  'payment:amex',
#  'payment:android_pay',
#  'payment:apple_pay',
#  'payment:bbqcoin',
#  'payment:bitcoin',
#  'payment:campus_cash',
#  'payment:cash',
#  'payment:cheque',
#  'payment:cheques',
#  'payment:coinkite',
#  'payment:coins',
#  'payment:credit_cards',
#  'payment:cryptocurrencies',
#  'payment:debit_cards',
#  'payment:diners_club',
#  'payment:discover',
#  'payment:discover_card',
#  'payment:electronic_purses',
#  'payment:gift_card',
#  'payment:interac',
#  'payment:jcb',
#  'payment:levelup',
#  'payment:litecoin',
#  'payment:maestro',
#  'payment:mastercard',
#  'payment:mcard',
#  'payment:meal_plan',
#  'payment:mobile_phone',
#  'payment:munch_money',
#  'payment:notes',
#  'payment:paypal',
#  'payment:visa',
#  'payment:visa_debit',
#  'phone',
#  'phone:tollfree',
#  'phone_1',
#  'postal_code',
#  'power_supply',
#  'price',
#  'price:coffee',
#  'ramp',
#  'recycling:coffee_cups',
#  'redwood_city_ca:addr_id',
#  'ref',
#  'ref:miaaddr',
#  'ref:store_number',
#  'reservation',
#  'restaurant',
#  'review',
#  'rooms',
#  'seasonal',
#  'seating',
#  'seating_area',
#  'seats',
#  'self_checkout',
#  'self_service',
#  'service',
#  'service:bicycle:cleaning',
#  'service:bicycle:parts',
#  'service:bicycle:pump',
#  'service:bicycle:repair',
#  'service:bicycle:tools',
#  'shop',
#  'short_name',
#  'smoking',
#  'smoking:outside',
#  'source',
#  'source:addr',
#  'source:addr:housenumber',
#  'source:addr:id',
#  'source:date',
#  'source:internet_access',
#  'source:level',
#  'source:location',
#  'source:name',
#  'source:opening_hours',
#  'source:payment',
#  'source:phone',
#  'source:position',
#  'source_1',
#  'source_ref',
#  'source_url',
#  'sport',
#  'stars',
#  'start_date',
#  'step_count',
#  'store_name',
#  'store_ref',
#  'suite',
#  'suite_1',
#  'surface',
#  'surrey:addrid',
#  'surrey:date',
#  'surveillance',
#  'surveillance:type',
#  'survey:date',
#  'sym',
#  'takeaway',
#  'takeout',
#  'terrace',
#  'terrasse',
#  'time',
#  'toilets',
#  'toilets:access',
#  'toilets:drinking_water',
#  'toilets:female',
#  'toilets:for:female',
#  'toilets:for:male',
#  'toilets:male',
#  'toilets:occupancy',
#  'toilets:wheelchair',
#  'tourism',
#  'tourism:disused',
#  'twitter',
#  'type',
#  'undefined',
#  'url',
#  'usar_addr:edit_date',
#  'washroom',
#  'washrooms',
#  'website',
#  'website:related',
#  'wheelchair',
#  'wheelchair:description',
#  'wheelchair:description:en',
#  'wheelchair_toilet',
#  'wifi',
#  'wifi_provider',
#  'wikidata',
#  'wikimedia_commons',
#  'wikipedia',
#  'wine',
#  'wine_tasting',
#  'wlan',
#  'yelp']

# %%
cafes.isnull().sum() / len(cafes)
# Out:
# id                          0.000000
# @id                         0.000000
# amenity                     0.000000
# building                    0.998607
# cuisine                     0.552107
# name                        0.030798
# operator                    0.970932
# wheelchair                  0.950800
# website                     0.814443
# addr:city                   0.763946
# addr:country                0.961514
# addr:housenumber            0.665257
# addr:province               0.971412
# addr:street                 0.657954
# internet_access             0.852784
# opening_hours               0.866766
# payment:amex                0.985154
# payment:coins               0.984817
# payment:notes               0.984817
# recycling:coffee_cups       0.999856
# created_by                  0.995628
# addr:postcode               0.764186
# description                 0.992024
# hst_number                  0.999760
# self_checkout               0.999952
# capacity                    0.998847
# smoking                     0.948734
# wifi                        0.971748
# wheelchair:description      0.998462
# source                      0.943689
#                               ...
# name:nl                     0.999952
# source:phone                0.999952
# payment:cheque              0.999904
# dessert:type                0.999952
# payment:discover            0.999952
# payment:paypal              0.999952
# cat                         0.999952
# name:zh_pinyin              0.999952
# service:bicycle:cleaning    0.999952
# service:bicycle:parts       0.999952
# service:bicycle:pump        0.999952
# Door                        0.999952
# automatic_door              0.999952
# addr:street:prefix          0.999952
# black_owned                 0.999952
# ref:miaaddr                 0.999952
# service                     0.999952
# name:etymology:wikidata     0.999952
# name:pt                     0.999904
# karaoke                     0.999952
# gambling                    0.999952
# reservation                 0.999952
# tourism:disused             0.999952
# indoor:level                0.999856
# landuse                     0.999952
# diet:raw                    0.999952
# name:it                     0.999952
# amenity:ice_cream           0.999952
# geometry                    0.000000
# count                       0.000000
# dtype: float64

# %%
cafes = cafes.T[cafes.isnull().sum() / len(cafes) < 0.6].T
cafes.sample(5)
# Out:
#                     id              @id amenity      cuisine           name  \
# 8790   node/2529582517  node/2529582517    cafe         None      Starbucks
# 3314   node/1151336635  node/1151336635    cafe         None      à la mode
# 1996    node/734278762   node/734278762    cafe         None  Corner Bakery
# 9262   node/2623014627  node/2623014627    cafe  coffee_shop      Starbucks
# 16476  node/4317203896  node/4317203896    cafe         None    Tim Hortons
#
#                                     geometry count
# 8790   POINT (-71.58915519999999 42.3393875)     1
# 3314          POINT (-123.134633 49.2724188)     1
# 1996          POINT (-77.0316782 38.8971432)     1
# 9262   POINT (-73.96366860000001 40.7659236)     1
# 16476   POINT (-78.37234909999999 44.274963)     1

# %%
del cafes['id']
del cafes['@id']
cafes.sample()
# Out:
#       amenity cuisine      name                         geometry count
# 12062    cafe    None  Flying M  POINT (-112.4353994 37.8322262)     1

# %%
us_geo = geopandas.read_file('us_20m.json')
us_geo.crs = {'init' :'epsg:4326'}
us_geo = us_geo.to_crs({'init': 'epsg:3395'})

# %%
us_geo.plot()
# plt.xlim((-2, -0.5))
plt.show()

# %%
us_geo = us_geo[(us_geo.NAME != "Hawaii") & (us_geo.NAME != "Alaska") & (us_geo.NAME != "Puerto Rico")]
us_geo.plot()
plt.show()

# %%
cafes = geopandas.GeoDataFrame(cafes)
cafes.crs = {'init' :'epsg:4326'}
cafes = cafes.to_crs({'init': 'epsg:3395'})

# %%
base = us_geo.plot(color='white', edgecolor='black', figsize=(20,20))
cafes.plot(ax=base, marker='o', color='green', markersize=1)
plt.show()

# %% [markdown]
# ### References
#
# Geopandas mapping: http://geopandas.org/mapping.html
